# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(100, 2, centers=2, random_state=2, cluster_std=1.5)

# %%
import plotly.express as px

px.scatter(x=X[:, 0], y=X[:, 1], color=y)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X, y);

# %%
import numpy as np


rng = np.random.RandomState(0)
Xnew = [-6, -14] + [14, 18] * rng.rand(2000, 2)
ynew = model.predict(Xnew)

# %%
import plotly.graph_objects as go

fig = go.Figure()
mark = dict(color=y, colorscale="RdBu", size=10)

fig.add_scatter(x=X[:, 0], y=X[:, 1], mode="markers", marker=dict(color=y, colorscale="RdBu", size=10), name="original")
fig.add_scatter(x=Xnew[:, 0], y=Xnew[:, 1], mode="markers", marker=dict(color=ynew, colorscale="RdBu"), opacity=0.3, name="predicted")
